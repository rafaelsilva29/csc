# %%
run predict.py
# Out:
# Nr Features: 13
# Shape X: (8735, 24, 13)
# Shape Y: (8735, 1)
# ---------- Begin Time Series Split Nº1 ----------
# > Fit the model, please wait...
# mae: 12.27%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº2 ----------
# > Fit the model, please wait...
# mae: 15.41%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº3 ----------
# > Fit the model, please wait...
# mae: 10.07%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº4 ----------
# > Fit the model, please wait...
# mae: 11.77%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº5 ----------
# > Fit the model, please wait...
# mae: 11.09%
# -------------------------------------------------
#
#
# Model: "sequential_2"
# _________________________________________________________________
# ...
