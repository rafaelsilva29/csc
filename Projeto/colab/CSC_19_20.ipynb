# %%
run predict.py
# Out:
# current_speed            0
# free_flow_speed          0
# current_travel_time      0
# free_flow_travel_time    0
# time_diff                0
# speed_diff               0
# Hour                     0
# Day of month             0
# Month (number)           0
# delay_in_seconds         0
# humidity                 0
# length_in_meters         0
# temperature              0
# dtype: int64
# Nr Features: 13
# Shape X: (3141, 24, 13)
# Shape Y: (3141, 1)
# ---------- Begin Time Series Split Nº1 ----------
# > Fit the model, please wait...
# mae: 13.00%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº2 ----------
# > Fit the model, please wait...
# mae: 12.39%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº3 ----------
# > Fit the model, please wait...
# mae: 8.75%
# -------------------------------------------------
#
#
# ---------- Begin Time Series Split Nº4 ----------
# ...
