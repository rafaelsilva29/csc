# %%
run predict.py
# Out:
# current_speed            0
# free_flow_speed          0
# current_travel_time      0
# free_flow_travel_time    0
# time_diff                0
# speed_diff               0
# Hour                     0
# Day of month             0
# Month (number)           0
# delay_in_seconds         0
# humidity                 0
# length_in_meters         0
# temperature              0
# dtype: int64
# Nr Features: 13
# Shape X: (3167, 24, 13)
# Shape Y: (3167, 1)
# ---------- Begin Time Series Split Nº1 ----------
# > Fit the model, please wait...
# Epoch 1/100
# 17/17 - 1s - loss: 0.6489 - mae: 0.7328 - val_loss: 0.4863 - val_mae: 0.6590 - lr: 0.0010
# Epoch 2/100
# 17/17 - 0s - loss: 0.3055 - mae: 0.4884 - val_loss: 0.2002 - val_mae: 0.4099 - lr: 0.0010
# Epoch 3/100
# 17/17 - 0s - loss: 0.2203 - mae: 0.3859 - val_loss: 0.1485 - val_mae: 0.3296 - lr: 0.0010
# Epoch 4/100
# 17/17 - 0s - loss: 0.1970 - mae: 0.3499 - val_loss: 0.1399 - val_mae: 0.3105 - lr: 0.0010
# Epoch 5/100
# ...
