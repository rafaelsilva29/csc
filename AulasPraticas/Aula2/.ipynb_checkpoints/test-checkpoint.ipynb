# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

print(50*'*'+' Parte 2 '+50*'*')
#tensorflow version being used
print('TF version:', tf.__version__)

#is tf executing eagerly? 
print(tf.executing_eagerly())
# Out:
# ************************************************** Parte 2 **************************************************
# TF version: 2.0.0-alpha0

# %%
#load mnist training and test data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

#we have 10 labels (0:Zero, 1:One, 2:Two, 3:Three, 4:Four, 5:Five, 6:Six, 7:Seven, 8:Eight, 9:Nine)
#each image is mapped to one single label. class names are not included in the dataset
labels = ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']

# %%
#data shape and cardinality
print('Train set shape', x_train.shape)
print('Train labels shape', y_train.shape)
print('Test set shape', x_test.shape)
print('Test labels shape', y_test.shape)
print('Number of training samples', len(x_train))
print('Number of testing samples', len(x_test))
# Out:
# Train set shape (60000, 28, 28)
# Train labels shape (60000,)
# Test set shape (10000, 28, 28)
# Test labels shape (10000,)
# Number of training samples 60000
# Number of testing samples 10000

# %%
#show a figure
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#plotting some numbers!
plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1) #Add a subplot as 5 x 5 
    plt.xticks([]) #get rid of labels
    plt.yticks([]) #get rid of labels
    plt.grid(False)
    plt.imshow(x_test[i], cmap="gray")
    plt.xlabel(labels[y_test[i]])
plt.show()

# %%
#reshape the input to have a list of 784 (28*28) and normalize it (/255)
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1]*x_train.shape[2]) 
x_train = x_train.astype('float32')/255
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1]*x_test.shape[2]) 
x_test = x_test.astype('float32')/255

# %%
#building a three-layer sequential model
model = tf.keras.Sequential([ 
    tf.keras.layers.Dense(64, activation='relu'), 
    tf.keras.layers.Dense(64, activation='relu'), 
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
#compiling the model
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#training it
model.fit(x_train, y_train, epochs=10, batch_size=256)

#evaluating it
print(50*'*'+' Accuracy '+50*'*')
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2, batch_size=256)
print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 1s 15us/sample - loss: 0.4982 - accuracy: 0.8643
# Epoch 2/10
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.2133 - accuracy: 0.9384
# Epoch 3/10
# 60000/60000 [==============================] - 1s 17us/sample - loss: 0.1573 - accuracy: 0.9541
# Epoch 4/10
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.1290 - accuracy: 0.9623
# Epoch 5/10
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.1078 - accuracy: 0.9681
# Epoch 6/10
# 60000/60000 [==============================] - 1s 16us/sample - loss: 0.0928 - accuracy: 0.9727
# Epoch 7/10
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.0821 - accuracy: 0.9755
# Epoch 8/10
# 60000/60000 [==============================] - 1s 17us/sample - loss: 0.0721 - accuracy: 0.9786
# Epoch 9/10
# 60000/60000 [==============================] - 1s 11us/sample - loss: 0.0645 - accuracy: 0.9808s - loss: 0
# Epoch 10/10
# 60000/60000 [==============================] - 1s 10us/sample - loss: 0.0576 - accuracy: 0.9827
# ************************************************** Accuracy **************************************************
# 10000/10000 - 0s - loss: 0.0920 - accuracy: 0.9730
#
# Test accuracy: 0.973

# %%
#finally, generating predictions (the output of the last layer)
print('\nGenerating predictions for the first fifteen samples...') 
predictions = model.predict(x_test, batch_size=256)

#prediction 0
print(predictions[0])
print(np.argmax(predictions[0]))
print(y_test[0])
print(labels[y_test[0]])
# Out:
# Generating predictions for the first fifteen samples...
# [2.8466309e-06 1.5253578e-08 9.6707758e-05 5.0501934e-05 7.3039370e-09
#  2.1927939e-08 5.7892401e-13 9.9984694e-01 2.8619354e-07 2.7021131e-06]
# 7
# 7
# Seven

# %%
print('Predictions shape:', predictions.shape)
error = 0
total = 0
for i, prediction in enumerate(predictions):
    #tf.argmax returns the INDEX with the largest value across axes of a tensor
    predicted_value = tf.argmax(prediction)
    if predicted_value.numpy() != y_test[i]:
        error = error + 1
    label = labels[y_test[i]]
    print('Predicted a %d. Real value is %s.' %(predicted_value, label))
    total = total + 1
# Out:
# Predictions shape: (10000, 10)
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Nine.
# Predicted a 7. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is Six.
# Predicted a 8. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# ...
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 3. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 7. Real value is Seven.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Three.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 8. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 8. Real value is Eight.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 5. Real value is Five.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 3. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 5. Real value is Five.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 5. Real value is Five.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Six.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 9. Real value is Nine.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 3. Real value is Three.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 4. Real value is Four.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 9. Real value is Nine.
# Predicted a 2. Real value is Two.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 5. Real value is Five.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 3. Real value is Three.
# Predicted a 9. Real value is Nine.
# Predicted a 1. Real value is One.
# Predicted a 4. Real value is Four.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 1. Real value is One.
# Predicted a 0. Real value is Zero.
# Predicted a 0. Real value is Zero.
# Predicted a 6. Real value is Six.
# Predicted a 2. Real value is Two.
# Predicted a 1. Real value is One.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 4. Real value is Four.
# Predicted a 6. Real value is Six.
# Predicted a 0. Real value is Zero.
# Predicted a 7. Real value is Seven.
# Predicted a 0. Real value is Zero.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 8. Real value is Eight.
# Predicted a 7. Real value is Seven.
# Predicted a 1. Real value is One.
# Predicted a 5. Real value is Five.
# Predicted a 2. Real value is Two.
# Predicted a 4. Real value is Four.
# Predicted a 9. Real value is Nine.
# Predicted a 4. Real value is Four.
# Predicted a 3. Real value is Three.
# Predicted a 6. Real value is Six.
# Predicted a 4. Real value is Four.
# Predicted a 1. Real value is One.
# Predicted a 7. Real value is Seven.
# Predicted a 2. Real value is Two.
# Predicted a 6. Real value is Six.
# Predicted a 6. Real value is Five.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.
# Predicted a 7. Real value is Seven.
# Predicted a 8. Real value is Eight.
# Predicted a 9. Real value is Nine.
# Predicted a 0. Real value is Zero.
# Predicted a 1. Real value is One.
# Predicted a 2. Real value is Two.
# Predicted a 3. Real value is Three.
# Predicted a 4. Real value is Four.
# Predicted a 5. Real value is Five.
# Predicted a 6. Real value is Six.

# %%
correct = total-error
accuracy = (correct/total) * 100
print('Total samples: %d, Correct: %d, Incorrect: %d, Accuracy: %f' %(total, correct, error, accuracy))
